# %% [markdown]
# <a href="https://colab.research.google.com/github/vilecruel/olgamanakova/blob/my-new-branch/13pz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Практическая 13

#Из исходного текстового файла (experience.txt) выбрать стаж работы.
#Посчитать количество полученных элементов.

import re

with open("experience.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

experience_list = []

for line in lines:
    match = re.search(r'\d+\s+(?:лет|года|год|месяцев|месяца|месяц).*', line)
    if match:
        experience_list.append(match.group())

count_elements = len(experience_list)

print("Найденный стаж работы:")
for item in experience_list:
    print("-", item)

print("\nКоличество полученных элементов:", count_elements)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1765/2238403621.py in <cell line: 0>()
#       6 import re
#       7
# ----> 8 with open("experience.txt", "r", encoding="utf-8") as file:
#       9     lines = file.readlines()
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experience.txt'
